# %%
import os
from dotenv import load_dotenv
from pprint import pprint

from azure.ai.evaluation import (
    AzureOpenAIModelConfiguration, 
    ToolCallAccuracyEvaluator, 
    IntentResolutionEvaluator, 
    TaskAdherenceEvaluator
)

load_dotenv("../../.env")

model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT"],
)

tool_call_accuracy = ToolCallAccuracyEvaluator(model_config=model_config)
intent_resolution = IntentResolutionEvaluator(model_config=model_config)
task_adherence = TaskAdherenceEvaluator(model_config=model_config)
# Out:
# Class ToolCallAccuracyEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntentResolutionEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class TaskAdherenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
from azure.ai.evaluation import evaluate

file_name = "bulk_agents_evaluation_dataset.jsonl"

response = evaluate(
    data=file_name,
    evaluators={
        "tool_call_accuracy": tool_call_accuracy,
        "intent_resolution": intent_resolution,
        "task_adherence": task_adherence,
    },
    azure_ai_project={
        "subscription_id": os.environ["SUBSCRIPTION_ID"],
        "project_name": os.environ["PROJECT_NAME"],
        "resource_group_name": os.environ["RG_NAME"],
    }
)
pprint(f'AI Foundary URL: {response.get("studio_url")}')
# Out:
# [2025-05-22 10:02:43 +0100][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-22 10:02:43 +0100][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-22 10:02:43 +0100][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-05-22 10:02:43 +0100][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_tool_call_accuracy_20250522_100242_330269, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_tool_call_accuracy_20250522_100242_330269\logs.txt
# [2025-05-22 10:02:43 +0100][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_task_adherence_20250522_100242_346288, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_task_adherence_20250522_100242_346288\logs.txt
# [2025-05-22 10:02:43 +0100][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_intent_resolution_20250522_100242_334524, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_intent_resolution_20250522_100242_334524\logs.txt
# 2025-05-22 10:02:43 +0100   33452 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-22 10:02:43 +0100   33452 execution.bulk     INFO     Finished 6 / 6 lines.
# 2025-05-22 10:02:43 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 0.02 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_tool_call_accuracy_20250522_100242_330269"
# Run status: "Completed"
# Start time: "2025-05-22 10:02:42.385397+01:00"
# Duration: "0:00:02.629846"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_tool_call_accuracy_20250522_100242_330269"
#
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 1 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 6.21 seconds. Estimated time for incomplete lines: 31.05 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 2 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 3.22 seconds. Estimated time for incomplete lines: 12.88 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 3 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 2.16 seconds. Estimated time for incomplete lines: 6.48 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 1 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 6.55 seconds. Estimated time for incomplete lines: 32.75 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 2 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 3.42 seconds. Estimated time for incomplete lines: 13.68 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 4 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.75 seconds. Estimated time for incomplete lines: 3.5 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 5 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.41 seconds. Estimated time for incomplete lines: 1.41 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 6 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.18 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 3 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 2.48 seconds. Estimated time for incomplete lines: 7.44 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 4 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.89 seconds. Estimated time for incomplete lines: 3.78 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 5 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.56 seconds. Estimated time for incomplete lines: 1.56 seconds.
# 2025-05-22 10:02:43 +0100   33452 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 1 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 6.21 seconds. Estimated time for incomplete lines: 31.05 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 2 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 3.22 seconds. Estimated time for incomplete lines: 12.88 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 3 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 2.16 seconds. Estimated time for incomplete lines: 6.48 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 4 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.75 seconds. Estimated time for incomplete lines: 3.5 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 5 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.41 seconds. Estimated time for incomplete lines: 1.41 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 6 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.18 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_intent_resolution_20250522_100242_334524"
# Run status: "Completed"
# Start time: "2025-05-22 10:02:42.386707+01:00"
# Duration: "0:00:09.250337"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_intent_resolution_20250522_100242_334524"
#
# 2025-05-22 10:02:52 +0100   33452 execution.bulk     INFO     Finished 6 / 6 lines.
# 2025-05-22 10:02:52 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.37 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-05-22 10:02:43 +0100   33452 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 1 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 6.55 seconds. Estimated time for incomplete lines: 32.75 seconds.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Finished 2 / 6 lines.
# 2025-05-22 10:02:50 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 3.42 seconds. Estimated time for incomplete lines: 13.68 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 3 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 2.48 seconds. Estimated time for incomplete lines: 7.44 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 4 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.89 seconds. Estimated time for incomplete lines: 3.78 seconds.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Finished 5 / 6 lines.
# 2025-05-22 10:02:51 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.56 seconds. Estimated time for incomplete lines: 1.56 seconds.
# 2025-05-22 10:02:52 +0100   33452 execution.bulk     INFO     Finished 6 / 6 lines.
# 2025-05-22 10:02:52 +0100   33452 execution.bulk     INFO     Average execution time for completed lines: 1.37 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_task_adherence_20250522_100242_346288"
# Run status: "Completed"
# Start time: "2025-05-22 10:02:42.393337+01:00"
# Duration: "0:00:10.219309"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_task_adherence_20250522_100242_346288"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "tool_call_accuracy": {
#         "status": "Completed",
#         "duration": "0:00:02.629846",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_tool_call_accuracy_20250522_100242_330269"
#     },
#     "intent_resolution": {
#         "status": "Completed",
#         "duration": "0:00:09.250337",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_intent_resolution_20250522_100242_334524"
#     },
#     "task_adherence": {
#         "status": "Completed",
#         "duration": "0:00:10.219309",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_task_adherence_20250522_100242_346288"
#     }
# }
#
# ====================================================
#
# ('AI Foundary URL: '
#  'https://ai.azure.com/build/evaluation/e3baf00b-ef2f-46fa-82fb-7257fe631442?wsid=/subscriptions/65a513ce-bb5d-4ed5-92b1-fa601d510a15/resourceGroups/agentai/providers/Microsoft.MachineLearningServices/workspaces/genaiops-demo')
